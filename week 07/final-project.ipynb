# %% [markdown]
# # Predicting Prices of second hand cars
# This project aims to predict the prices of second hand cars in the market, using supervised learning ML Models, to help potential customers be better prepared in their search for a second hand car, by having a better understanding/estimation of the price. Here are the steps we will follow to achieve this:
# - Get the data
# - Clean the data
# - Perform EDA
# - Train Model (s)
# - Evaluate the models) using various metrics (R2, MSE, MAE, RMSE).

# %% [markdown]
# # Data
# Used car price Dataset. (2025, June 3). Kaggle. https://www.kaggle.com/datasets/rishabhkarn/used-car-dataset/data
#
# About Dataset
# 🚗 Used Car Price Dataset: A dataset for predicting used car price 📊
# Dive into the world of used cars with our dataset, perfect for predicting prices. It's a carefully selected set of data that car enthusiasts, analysts, and data scientists will find valuable. Whether you're curious or looking to analyze, this dataset is your guide to understanding the dynamics of how used cars are valued.
#
# Key Features:
#
# 🛣️ Rich Attributes: Explore a number of attributes, including mileage, model year, fuel type, transmission, and more, providing a 360-degree view of each vehicle's specifications.
#
# 📉 Depreciation Insights: Uncover patterns in vehicle depreciation over time and across different makes and models, empowering you to make informed predictions about future price trends.
#
# 📱 Technological Integration: Seamlessly integrate our dataset into your predictive modeling pipelines, harnessing the power of technology to foresee changes in the used car market.
#
# ### Dataset Description:
#
# 1552 Rows, 15 Columns
#
# Attributes:
#
# - car_name
# - registration_year
# - insurance_validity
# - fuel_type
# - seats
# - kms_driven
# - ownership
# - transmission
# - manufacturing_year
# - mileage(kmpl)
# - engine(cc)
# - max_power(bhp)
# - torque(Nm)
# - price(in lakhs)

# %% [markdown]
# # Models
# In this project, we are going to be using 2 Models, Linear Regression and AdaBoost Regressor. We chose these models for the following reasons
# - Diversity in Approaches: By choosing both Linear Regression and AdaBoost Regressor, we leverage the strengths of both linear models and ensemble methods. This diversity allows us to compare
# and understand the impact of linearity and non-linearity in the data.
# - Model Comparison and Validation: Using both models provides a comprehensive understanding of the dataset. It allows us to validate whether a simple linear model suffices or if a more complex
# ensemble approach yields better results, considering the trade-offs.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.feature_selection import RFECV
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# # Load the data

# %%
df = pd.read_csv('./Used Car Dataset.csv',index_col=0)
df. head ()
# Out:
#                                             car_name registration_year  \
# 0                    2017 Mercedes-Benz S-Class S400            Jul-17
# 1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI            Jan-21
# 2                       2018 BMW X1 sDrive 20d xLine            Sep-18
# 3                           2019 Kia Seltos GTX Plus            Dec-19
# 4                    2019 Skoda Superb LK 1.8 TSI AT            Aug-19
#
#   insurance_validity fuel_type  seats  kms_driven   ownsership transmission  \
# 0      Comprehensive    Petrol      5       56000  First Owner    Automatic
# 1      Comprehensive    Petrol      5       30615  First Owner    Automatic
# 2      Comprehensive    Diesel      5       24000  First Owner    Automatic
# 3      Comprehensive    Petrol      5       18378  First Owner       Manual
# 4      Comprehensive    Petrol      5       44900  First Owner    Automatic
#
#   manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# 0               2017           7.81      2996.0          2996.0       333.0
# 1               2020          17.40       999.0           999.0      9863.0
# 2               2018          20.68      1995.0          1995.0       188.0
# 3               2019          16.50      1353.0          1353.0     13808.0
# 4               2019          14.67      1798.0          1798.0     17746.0
#
#    price(in lakhs)
# 0            63.75
# 1             8.99
# 2            23.75
# 3            13.56
# 4            24.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1553 entries, 0 to 1552
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            1553 non-null   object
#  1   registration_year   1553 non-null   object
#  2   insurance_validity  1553 non-null   object
#  3   fuel_type           1553 non-null   object
#  4   seats               1553 non-null   int64
#  5   kms_driven          1553 non-null   int64
#  6   ownsership          1553 non-null   object
#  7   transmission        1553 non-null   object
#  8   manufacturing_year  1553 non-null   object
#  9   mileage(kmpl)       1550 non-null   float64
#  10  engine(cc)          1550 non-null   float64
#  11  max_power(bhp)      1550 non-null   float64
#  12  torque(Nm)          1549 non-null   float64
#  13  price(in lakhs)     1553 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 182.0+ KB

# %% [markdown]
# # EDA & Cleaning
# First we check if there are any NaN Values

# %%
df.isna().sum()
# Out:
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         3
# engine(cc)            3
# max_power(bhp)        3
# torque(Nm)            4
# price(in lakhs)       0
# dtype: int64

# %%
df[df[['mileage(kmpl)','engine(cc)','max_power(bhp)','torque(Nm)']].isna().any(axis = 1)]
# Out:
#                           car_name registration_year insurance_validity  \
# 462  2022 BMW X3 xDrive30i M Sport            Feb-22           Zero Dep
# 513            2011 Toyota Etios G            Dec-11      Comprehensive
# 533            2011 Toyota Etios G            Dec-11      Comprehensive
# 589            2011 Toyota Etios G            Jul-11      Comprehensive
#
#     fuel_type  seats  kms_driven   ownsership transmission manufacturing_year  \
# 462    Petrol      5        8450  First Owner    Automatic               2022
# 513    Petrol      5       51710  First Owner       Manual               2011
# 533    Petrol      5       51710  First Owner       Manual               2011
# 589    Petrol      5       54214  First Owner       Manual               2011
#
#      mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)
# 462           19.0         5.0             5.0         NaN            71.90
# 513            NaN         NaN             NaN         NaN             2.48
# 533            NaN         NaN             NaN         NaN             2.48
# 589            NaN         NaN             NaN         NaN             2.55

# %%
df[df['car_name'] == '2011 Toyota Etios G']
# Out:
#                 car_name registration_year insurance_validity fuel_type  \
# 513  2011 Toyota Etios G            Dec-11      Comprehensive    Petrol
# 533  2011 Toyota Etios G            Dec-11      Comprehensive    Petrol
# 589  2011 Toyota Etios G            Jul-11      Comprehensive    Petrol
#
#      seats  kms_driven   ownsership transmission manufacturing_year  \
# 513      5       51710  First Owner       Manual               2011
# 533      5       51710  First Owner       Manual               2011
# 589      5       54214  First Owner       Manual               2011
#
#      mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)
# 513            NaN         NaN             NaN         NaN             2.48
# 533            NaN         NaN             NaN         NaN             2.48
# 589            NaN         NaN             NaN         NaN             2.55

# %%
df[df['car_name'] == '2022 BMW X3 xDrive30i M Sport']
# Out:
#                           car_name registration_year insurance_validity  \
# 462  2022 BMW X3 xDrive30i M Sport            Feb-22           Zero Dep
#
#     fuel_type  seats  kms_driven   ownsership transmission manufacturing_year  \
# 462    Petrol      5        8450  First Owner    Automatic               2022
#
#      mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)
# 462           19.0         5.0             5.0         NaN             71.9

# %% [markdown]
# Since all the NaN values are just in these 3 rows, and these 2 cars do not have any other rows, we will be removing them from data.

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1549 entries, 0 to 1552
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            1549 non-null   object
#  1   registration_year   1549 non-null   object
#  2   insurance_validity  1549 non-null   object
#  3   fuel_type           1549 non-null   object
#  4   seats               1549 non-null   int64
#  5   kms_driven          1549 non-null   int64
#  6   ownsership          1549 non-null   object
#  7   transmission        1549 non-null   object
#  8   manufacturing_year  1549 non-null   object
#  9   mileage(kmpl)       1549 non-null   float64
#  10  engine(cc)          1549 non-null   float64
#  11  max_power(bhp)      1549 non-null   float64
#  12  torque(Nm)          1549 non-null   float64
#  13  price(in lakhs)     1549 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 181.5+ KB

# %% [markdown]
# We are dropping the registration_year col, as it is pretty similar to the manufacturing_year col

# %%
df = df.drop('registration_year',axis = 1)

# %% [markdown]
# We check for duplicate data

# %%
df.duplicated().sum()
# Out:
# 420

# %%
df.loc[df.duplicated]
# Out:
#                                      car_name     insurance_validity  \
# 40                2021 MG Gloster Savvy 6-Str          Comprehensive
# 41             2010 Maruti Swift 1.2 VXi BSII          Comprehensive
# 42              2015 Honda City i VTEC CVT VX  Third Party insurance
# 43              2011 Maruti Wagon R LXI BSIII          Comprehensive
# 44                        2015 Audi A6 35 TDI          Comprehensive
# ...                                       ...                    ...
# 1503                  2013 Hyundai i10 Sportz          Comprehensive
# 1510  2019 Jeep Compass 1.4 Limited Plus BSIV          Comprehensive
# 1511     2021 Toyota Urban cruiser Premium AT               Zero Dep
# 1512            2018 Hyundai Grand i10 Sportz          Comprehensive
# 1518           2019 BMW X7 xDrive 40i M Sport          Comprehensive
#
#      fuel_type  seats  kms_driven    ownsership transmission  \
# 40      Diesel      6       35000   First Owner    Automatic
# 41      Petrol      5      100525   First Owner       Manual
# 42      Petrol      5       83000  Second Owner    Automatic
# 43      Petrol      5       40191  Second Owner       Manual
# 44      Diesel      5       62152   First Owner    Automatic
# ...        ...    ...         ...           ...          ...
# 1503    Petrol      5        1800   First Owner       Manual
# 1510    Petrol      5       34000   First Owner    Automatic
# 1511    Petrol      5       30000   First Owner    Automatic
# 1512    Petrol      5       22700   First Owner       Manual
# 1518    Petrol      7       28000   First Owner    Automatic
#
#      manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  \
# 40                 2021          12.40      1996.0          1996.0
# 41                 2010          16.10      1197.0          1197.0
# 42                 2015          18.00      1497.0          1497.0
# 43                 2011         998.00       671.0           671.0
# 44                 2015          18.53      1968.0          1968.0
# ...                 ...            ...         ...             ...
# 1503               2013          20.36      1197.0          1197.0
# 1510               2019          16.00      1368.0          1368.0
# 1511               2021          18.76      1462.0          1462.0
# 1512               2018          18.90      1197.0          1197.0
# 1518               2019          10.54      2998.0          2998.0
#
#       torque(Nm)  price(in lakhs)
# 40       21501.0            35.00
# 41          85.0             2.09
# 42        1173.0             6.25
# 43          90.0             2.12
# 44       18774.0            20.00
# ...          ...              ...
# 1503       789.0             3.15
# 1510     16077.0            17.50
# 1511     10326.0            11.40
# 1512      8186.0             5.45
# 1518     33525.0            99.00
#
# [420 rows x 13 columns]

# %% [markdown]
# We delete the duplicate data

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1129 entries, 0 to 1552
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            1129 non-null   object
#  1   insurance_validity  1129 non-null   object
#  2   fuel_type           1129 non-null   object
#  3   seats               1129 non-null   int64
#  4   kms_driven          1129 non-null   int64
#  5   ownsership          1129 non-null   object
#  6   transmission        1129 non-null   object
#  7   manufacturing_year  1129 non-null   object
#  8   mileage(kmpl)       1129 non-null   float64
#  9   engine(cc)          1129 non-null   float64
#  10  max_power(bhp)      1129 non-null   float64
#  11  torque(Nm)          1129 non-null   float64
#  12  price(in lakhs)     1129 non-null   float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 123.5+ KB

# %% [markdown]
# Splitting the car_name col into car_model and car_maker cols, for further analysis

# %%
df['car_model'] = df['car_name'].str.split().str[2:].str.join('')
df['car_maker'] = df['car_name'].str.split().str[1:2].str.join('')
df
# Out:
#                                                car_name  \
# 0                       2017 Mercedes-Benz S-Class S400
# 1     2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2                          2018 BMW X1 sDrive 20d xLine
# 3                              2019 Kia Seltos GTX Plus
# 4                       2019 Skoda Superb LK 1.8 TSI AT
# ...                                                 ...
# 1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550                           2017 Honda WR-V i-VTEC S
# 1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552                        2018 Maruti Swift Dzire VXI
#
#          insurance_validity fuel_type  seats  kms_driven    ownsership  \
# 0             Comprehensive    Petrol      5       56000   First Owner
# 1             Comprehensive    Petrol      5       30615   First Owner
# 2             Comprehensive    Diesel      5       24000   First Owner
# 3             Comprehensive    Petrol      5       18378   First Owner
# 4             Comprehensive    Petrol      5       44900   First Owner
# ...                     ...       ...    ...         ...           ...
# 1548          Comprehensive    Diesel      5       35000   First Owner
# 1549  Third Party insurance    Petrol      5       10000        999 cc
# 1550          Comprehensive    Petrol      5       49000   First Owner
# 1551          Comprehensive    Petrol      5       40000  Second Owner
# 1552          Comprehensive    Petrol      5       34756   First Owner
#
#      transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 0       Automatic               2017           7.81      2996.0
# 1       Automatic               2020          17.40       999.0
# 2       Automatic               2018          20.68      1995.0
# 3          Manual               2019          16.50      1353.0
# 4       Automatic               2019          14.67      1798.0
# ...           ...                ...            ...         ...
# 1548    Automatic               2020        1493.00     11345.0
# 1549         2022     Power Steering         999.00      6706.0
# 1550       Manual               2017          17.50      1199.0
# 1551       Manual               2018          18.78       999.0
# 1552       Manual               2018          20.85      1197.0
#
#       max_power(bhp)  torque(Nm)  price(in lakhs)  \
# 0             2996.0       333.0            63.75
# 1              999.0      9863.0             8.99
# 2             1995.0       188.0            23.75
# 3             1353.0     13808.0            13.56
# 4             1798.0     17746.0            24.00
# ...              ...         ...              ...
# 1548         11345.0       250.0            17.41
# 1549          6706.0        91.0             3.98
# 1550          1199.0       887.0             5.85
# 1551           999.0        75.0             4.75
# 1552          1197.0      8314.0             6.10
#
#                             car_model      car_maker
# 0                         S-ClassS400  Mercedes-Benz
# 1     MagniteTurboCVTXVPremiumOptBSVI         Nissan
# 2                    X1sDrive20dxLine            BMW
# 3                       SeltosGTXPlus            Kia
# 4                    SuperbLK1.8TSIAT          Skoda
# ...                               ...            ...
# 1548           CretaSXOptDieselATBSVI        Hyundai
# 1549                KWID1.0RXLOptBSVI        Renault
# 1550                      WR-Vi-VTECS          Honda
# 1551            Polo1.0MPIComfortline     Volkswagen
# 1552                    SwiftDzireVXI         Maruti
#
# [1129 rows x 15 columns]

# %%
df.describe()
# Out:
#               seats     kms_driven  mileage(kmpl)    engine(cc)  \
# count   1129.000000    1129.000000    1129.000000  1.129000e+03
# mean      64.533215   53175.497786     221.419362  1.154669e+10
# std     1993.857832   43141.973771     557.662692  1.937050e+11
# min        4.000000     620.000000       7.810000  1.700000e+01
# 25%        5.000000   30000.000000      16.550000  1.197000e+03
# 50%        5.000000   49000.000000      18.900000  1.461000e+03
# 75%        5.000000   70000.000000      22.350000  1.991000e+03
# max    67000.000000  810000.000000    3996.000000  3.258640e+12
#
#        max_power(bhp)    torque(Nm)  price(in lakhs)
# count    1.129000e+03  1.129000e+03      1129.000000
# mean     1.154669e+10  1.443523e+04       159.872019
# std      1.937050e+11  9.555439e+04      3509.950855
# min      1.700000e+01  5.000000e+00         1.000000
# 25%      1.197000e+03  4.300000e+02         4.500000
# 50%      1.461000e+03  1.176000e+03         6.750000
# 75%      1.991000e+03  8.850000e+03        14.900000
# max      3.258640e+12  1.464800e+06     95000.000000

# %%
df.describe(include='object')
# Out:
#                             car_name insurance_validity fuel_type  \
# count                           1129               1129      1129
# unique                           923                  6         4
# top     2015 Hyundai Grand i10 Magna      Comprehensive    Petrol
# freq                               8                787       748
#
#          ownsership transmission manufacturing_year      car_model car_maker
# count          1129         1129               1129           1129      1129
# unique           22           13                 19            692        28
# top     First Owner       Manual               2018  Grandi10Magna    Maruti
# freq            918          644                172             15       254

# %%
brand_counts = pd.DataFrame(df['car_maker'].value_counts())
brand_counts.head(10)
# Out:
#                count
# car_maker
# Maruti           254
# Hyundai          240
# Honda            130
# Mercedes-Benz     97
# BMW               60
# Toyota            46
# Audi              40
# Tata              38
# Mahindra          33
# Ford              25

# %%
df['car_maker'].value_counts().head(10).plot(kind='barh')
plt.show()

# %% [markdown]
# We will now map each of the car companies to their respective countries. This will provide some additional insights into the data.

# %%
brand_country_map = {
    'Maruti': 'India',
    'Hyundai': 'South Korea',
    'Honda': 'Japan',
    'Mercedes-Benz': 'Germany',
    'Toyota': 'Japan',
    'BMW': 'Germany',
    'Tata': 'India',
    'Audi': 'Germany',
    'Mahindra': 'India',
    'Ford': 'United States',
    'Renault': 'France',
    'Volkswagen': 'Germany',
    'Kia': 'South Korea',
    'Nissan': 'Japan',
    'Skoda': 'Czech Republic',
    'Jeep': 'Uinted states',
    'MG': 'United Kingdom',
    'Volvo': 'Sweden',
    'Jaguar': 'United Kingdom',
    'Land': 'United Kingdom',
    'Datsun': 'Japan',
    'Mitsubishi': 'Japan',
    'Porsche': 'Germany',
    'Mini': 'United Kingdom',
    'Isuzu': 'Japan',
    'Lexus': 'Japan',
    'Fiat': 'Italy',
    'Lamborghini': 'Italy'
}
df['origin_country'] = df['car_maker'].map(brand_country_map)
df.head()
# Out:
#                                             car_name insurance_validity  \
# 0                    2017 Mercedes-Benz S-Class S400      Comprehensive
# 1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI      Comprehensive
# 2                       2018 BMW X1 sDrive 20d xLine      Comprehensive
# 3                           2019 Kia Seltos GTX Plus      Comprehensive
# 4                    2019 Skoda Superb LK 1.8 TSI AT      Comprehensive
#
#   fuel_type  seats  kms_driven   ownsership transmission manufacturing_year  \
# 0    Petrol      5       56000  First Owner    Automatic               2017
# 1    Petrol      5       30615  First Owner    Automatic               2020
# 2    Diesel      5       24000  First Owner    Automatic               2018
# 3    Petrol      5       18378  First Owner       Manual               2019
# 4    Petrol      5       44900  First Owner    Automatic               2019
#
#    mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)  \
# 0           7.81      2996.0          2996.0       333.0            63.75
# 1          17.40       999.0           999.0      9863.0             8.99
# 2          20.68      1995.0          1995.0       188.0            23.75
# 3          16.50      1353.0          1353.0     13808.0            13.56
# 4          14.67      1798.0          1798.0     17746.0            24.00
#
#                          car_model      car_maker  origin_country
# 0                      S-ClassS400  Mercedes-Benz         Germany
# 1  MagniteTurboCVTXVPremiumOptBSVI         Nissan           Japan
# 2                 X1sDrive20dxLine            BMW         Germany
# 3                    SeltosGTXPlus            Kia     South Korea
# 4                 SuperbLK1.8TSIAT          Skoda  Czech Republic

# %%
df['origin_country'].value_counts().plot(kind='pie')
plt.figure(figsize=(15,5))
plt.show()

# %%
pd.DataFrame(df['origin_country'].value_counts())
# Out:
#                 count
# origin_country
# India             325
# South Korea       262
# Germany           221
# Japan             205
# United Kingdom     36
# United States      25
# France             21
# Czech Republic     11
# Uinted states      11
# Sweden             10
# Italy               2

# %%
df['insurance_validity'].value_counts().plot(kind='bar')
print(df['insurance_validity'].value_counts())
plt.show()
# Out:
# insurance_validity
# Comprehensive            787
# Third Party insurance    233
# Third Party               56
# Zero Dep                  51
# Petrol                     1
# Not Available              1
# Name: count, dtype: int64

# %% [markdown]
# In the insurance_validity col, we replace 'Third Party' values to 'Third Party insurance', as these should be the same

# %%
df ['insurance_validity'] = df['insurance_validity'].replace( 'Third Party', 'Third Party insurance')
df ['insurance_validity'].value_counts().plot(kind='bar')
plt.show()

# %%
df[df['insurance_validity']==('Not Available')]
# Out:
#                                car_name insurance_validity fuel_type  seats  \
# 946  2009 Mercedes-Benz S-Class S 350 L      Not Available    Petrol      5
#
#      kms_driven   ownsership transmission manufacturing_year  mileage(kmpl)  \
# 946       92762  Fifth Owner    Automatic               2009          10.13
#
#      engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)     car_model  \
# 946      3498.0          3498.0      3649.0             8.25  S-ClassS350L
#
#          car_maker origin_country
# 946  Mercedes-Benz        Germany

# %%
df[df['insurance_validity']==('Petrol')]
# Out:
#                                             car_name insurance_validity  \
# 798  2013 Mercedes-Benz E-Class E 200 CGI Avantgarde             Petrol
#
#     fuel_type  seats  kms_driven ownsership         transmission  \
# 798   5 Seats  67000        1796       2013  Power Windows Front
#
#     manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# 798    Air Conditioner          285.0        17.0            17.0         5.0
#
#      price(in lakhs)                 car_model      car_maker origin_country
# 798             16.5  E-ClassE200CGIAvantgarde  Mercedes-Benz        Germany

# %% [markdown]
# Deleting this row, as this has wrong values for many of the features

# %%
df = df.drop(df[df['insurance_validity'] == 'Petrol'].index)
df['insurance_validity'].value_counts()
# Out:
# insurance_validity
# Comprehensive            787
# Third Party insurance    289
# Zero Dep                  51
# Not Available              1
# Name: count, dtype: int64

# %%
df['fuel_type'].value_counts().plot(kind='bar')
plt.show()

# %%
df['seats'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.boxplot(df['kms_driven'],vert=False)
plt.title('The distrubution of kms_driven')
plt.xlabel('kms driven')
plt.figure(figsize=(15,5))
plt.show()

# %%
df[df['kms_driven'] > 200000]
# Out:
#                                     car_name insurance_validity fuel_type  \
# 1094    2020 Hyundai Venue SX Plus Turbo DCT           Zero Dep    Petrol
# 1131  2020 Ford Ecosport 1.5 Diesel Titanium      Comprehensive    Diesel
# 1420    2012 Toyota Innova 2.5 VX 7 STR BSIV      Comprehensive    Diesel
#
#       seats  kms_driven   ownsership transmission manufacturing_year  \
# 1094      5      790000  First Owner    Automatic               2020
# 1131      5      810000  First Owner       Manual               2020
# 1420      7      260000  First Owner       Manual               2012
#
#       mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)  \
# 1094          18.15       998.0           998.0     11835.0             9.75
# 1131          21.70      1498.0          1498.0      9896.0             9.00
# 1420          12.80      2494.0          2494.0       102.0             6.25
#
#                       car_model car_maker origin_country
# 1094        VenueSXPlusTurboDCT   Hyundai    South Korea
# 1131  Ecosport1.5DieselTitanium      Ford  United States
# 1420        Innova2.5VX7STRBSIV    Toyota          Japan

# %% [markdown]
# Even though we have a couple of outliers in this col, we can keep these as these practical values in reality

# %%
df['ownsership'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# There are a few values that are wrong in this col

# %%
curpt_rows = ~df['ownsership'].isin(['First Owner','Second Owner','Third Owner','Fifth Owner'])
df[curpt_rows]
# Out:
#                                                car_name  \
# 116                     2017 BMW 7 Series 730Ld M Sport
# 170       2014 Nissan Terrano XV 110 PS Limited Edition
# 210                 2023 Hyundai i20 N-Line N8 DCT BSVI
# 213                    2017 BMW X1 sDrive20d Expedition
# 228                       2020 MG Hector Plus Smart DCT
# 231                    2017 BMW X1 sDrive20d Expedition
# 269                    2017 BMW X1 sDrive20d Expedition
# 272              2021 BMW 2 Series Black Shadow Edition
# 361                            2014 Honda City i DTEC V
# 367                            2011 Honda City 1.5 S MT
# 404            2021 Ford Endeavour Titanium Plus 4X4 AT
# 466    2022 Mercedes-Benz A-Class Limousine A 200d BSVI
# 624                    2017 BMW X1 sDrive20d Expedition
# 692                    2017 BMW X1 sDrive20d Expedition
# 1042                    2018 Tata Tigor 1.2 Revotron XZ
# 1171                       2011 Maruti Wagon R LX Minor
# 1233                         2017 Maruti Ciaz 1.3 Alpha
# 1262                     2023 Nissan Magnite XV Premium
# 1287  2017 Hyundai Grand i10 1.2 Kappa Sportz Dual Tone
# 1291             2015 Volkswagen Vento 1.5 TDI Highline
# 1449         2014 Audi Q3 2.0 TFSI Quattro Premium Plus
# 1485                                2018 Isuzu MU-X 2WD
# 1505                   2016 Audi A3 35 TDI Premium Plus
# 1549                 2022 Renault KWID 1.0 RXL Opt BSVI
#
#          insurance_validity fuel_type  seats  kms_driven ownsership  \
# 116   Third Party insurance    Diesel      5       60000    2993 cc
# 170   Third Party insurance    Diesel      5      100000    1461 cc
# 210   Third Party insurance    Petrol      5       10000     998 cc
# 213   Third Party insurance    Diesel      5       30000    1995 cc
# 228   Third Party insurance    Petrol      6       20000    1451 cc
# 231   Third Party insurance    Diesel      5       32000    1995 cc
# 269   Third Party insurance    Diesel      5       32000    1995 cc
# 272   Third Party insurance    Petrol      4       40000    1998 cc
# 361   Third Party insurance    Diesel      5       80000    1498 cc
# 367   Third Party insurance    Petrol      5      110000    1497 cc
# 404   Third Party insurance    Diesel      7       20000    1996 cc
# 466   Third Party insurance    Diesel      5       10000    1950 cc
# 624   Third Party insurance    Diesel      5       30000    1995 cc
# 692   Third Party insurance    Diesel      5       31500    1995 cc
# 1042  Third Party insurance    Petrol      5       60000    1199 cc
# 1171  Third Party insurance    Petrol      5       60000     998 cc
# 1233  Third Party insurance    Diesel      5       32141    1248 cc
# 1262  Third Party insurance    Petrol      5       10000     999 cc
# 1287  Third Party insurance    Petrol      5       70000    1197 cc
# 1291  Third Party insurance    Diesel      5       90000    1498 cc
# 1449  Third Party insurance    Petrol      5       90000    1984 cc
# 1485  Third Party insurance    Diesel      7       40000    2999 cc
# 1505  Third Party insurance    Diesel      5       80000    1968 cc
# 1549  Third Party insurance    Petrol      5       10000     999 cc
#
#      transmission   manufacturing_year  mileage(kmpl)  engine(cc)  \
# 116          2017       Power Steering        2993.00     26149.0
# 170          2014       Power Steering        1461.00      1085.0
# 210          2023       Power Steering         998.00     11841.0
# 213          2017       Power Steering        1995.00       188.0
# 228          2020  Power Windows Front        1451.00       141.0
# 231          2017       Power Steering        1995.00       188.0
# 269          2017       Power Steering        1995.00       188.0
# 272          2021       Power Steering        1998.00     18740.0
# 361          2014       Power Steering        1498.00       986.0
# 367          2011       Power Steering        1497.00   1186600.0
# 404          2021       Power Steering        1996.00     16762.0
# 466          2022       Power Steering         147.51       320.0
# 624          2017       Power Steering        1995.00       188.0
# 692          2017       Power Steering        1995.00       188.0
# 1042         2018       Power Steering        1199.00        84.0
# 1171         2011       Power Steering         998.00       671.0
# 1233         2017       Power Steering        1248.00       885.0
# 1262         2023       Power Steering         999.00      7102.0
# 1287         2017       Power Steering        1197.00      8186.0
# 1291         2015       Power Steering        1498.00      1032.0
# 1449         2014       Power Steering        1984.00       207.0
# 1485         2018       Power Steering        2999.00     17457.0
# 1505         2016       Power Steering        1968.00       143.0
# 1549         2022       Power Steering         999.00      6706.0
#
#       max_power(bhp)  torque(Nm)  price(in lakhs)  \
# 116          26149.0       620.0            55.00
# 170           1085.0       248.0             6.00
# 210          11841.0       172.0            11.70
# 213            188.0       400.0            19.50
# 228            141.0       250.0            17.50
# 231            188.0       400.0            18.20
# 269            188.0       400.0            19.50
# 272          18740.0       280.0            32.00
# 361            986.0       200.0             4.75
# 367        1186600.0   1464800.0             3.50
# 404          16762.0       420.0            32.00
# 466            320.0        17.0            42.00
# 624            188.0       400.0            18.20
# 692            188.0       400.0            19.50
# 1042            84.0       114.0             4.75
# 1171           671.0        90.0             1.70
# 1233           885.0       200.0             6.00
# 1262          7102.0        96.0             8.50
# 1287          8186.0     11375.0             4.00
# 1291          1032.0       250.0             3.50
# 1449           207.0       300.0             8.00
# 1485         17457.0       380.0            21.00
# 1505           143.0       320.0            15.30
# 1549          6706.0        91.0             3.98
#
#                            car_model      car_maker  origin_country
# 116               7Series730LdMSport            BMW         Germany
# 170     TerranoXV110PSLimitedEdition         Nissan           Japan
# 210               i20N-LineN8DCTBSVI        Hyundai     South Korea
# 213            X1sDrive20dExpedition            BMW         Germany
# 228               HectorPlusSmartDCT             MG  United Kingdom
# 231            X1sDrive20dExpedition            BMW         Germany
# 269            X1sDrive20dExpedition            BMW         Germany
# 272        2SeriesBlackShadowEdition            BMW         Germany
# 361                       CityiDTECV          Honda           Japan
# 367                       City1.5SMT          Honda           Japan
# 404       EndeavourTitaniumPlus4X4AT           Ford   United States
# 466        A-ClassLimousineA200dBSVI  Mercedes-Benz         Germany
# 624            X1sDrive20dExpedition            BMW         Germany
# 692            X1sDrive20dExpedition            BMW         Germany
# 1042              Tigor1.2RevotronXZ           Tata           India
# 1171                   WagonRLXMinor         Maruti           India
# 1233                    Ciaz1.3Alpha         Maruti           India
# 1262                MagniteXVPremium         Nissan           Japan
# 1287  Grandi101.2KappaSportzDualTone        Hyundai     South Korea
# 1291             Vento1.5TDIHighline     Volkswagen         Germany
# 1449     Q32.0TFSIQuattroPremiumPlus           Audi         Germany
# 1485                         MU-X2WD          Isuzu           Japan
# 1505              A335TDIPremiumPlus           Audi         Germany
# 1549               KWID1.0RXLOptBSVI        Renault          France

# %% [markdown]
# Even though we have a couple of outliers in this col, we can keep these as these practical values in reality

# %%
df['ownsership'].value_counts().plot(kind='barh')
plt.show()

# %% [markdown]
# There are a few values that are wrong in this col

# %%
curpt_rows = ~df['ownsership'].isin(['First Owner','Second Owner','Third Owner','Fifth Owner'])
df[curpt_rows]
# Out:
#                                                car_name  \
# 116                     2017 BMW 7 Series 730Ld M Sport
# 170       2014 Nissan Terrano XV 110 PS Limited Edition
# 210                 2023 Hyundai i20 N-Line N8 DCT BSVI
# 213                    2017 BMW X1 sDrive20d Expedition
# 228                       2020 MG Hector Plus Smart DCT
# 231                    2017 BMW X1 sDrive20d Expedition
# 269                    2017 BMW X1 sDrive20d Expedition
# 272              2021 BMW 2 Series Black Shadow Edition
# 361                            2014 Honda City i DTEC V
# 367                            2011 Honda City 1.5 S MT
# 404            2021 Ford Endeavour Titanium Plus 4X4 AT
# 466    2022 Mercedes-Benz A-Class Limousine A 200d BSVI
# 624                    2017 BMW X1 sDrive20d Expedition
# 692                    2017 BMW X1 sDrive20d Expedition
# 1042                    2018 Tata Tigor 1.2 Revotron XZ
# 1171                       2011 Maruti Wagon R LX Minor
# 1233                         2017 Maruti Ciaz 1.3 Alpha
# 1262                     2023 Nissan Magnite XV Premium
# 1287  2017 Hyundai Grand i10 1.2 Kappa Sportz Dual Tone
# 1291             2015 Volkswagen Vento 1.5 TDI Highline
# 1449         2014 Audi Q3 2.0 TFSI Quattro Premium Plus
# 1485                                2018 Isuzu MU-X 2WD
# 1505                   2016 Audi A3 35 TDI Premium Plus
# 1549                 2022 Renault KWID 1.0 RXL Opt BSVI
#
#          insurance_validity fuel_type  seats  kms_driven ownsership  \
# 116   Third Party insurance    Diesel      5       60000    2993 cc
# 170   Third Party insurance    Diesel      5      100000    1461 cc
# 210   Third Party insurance    Petrol      5       10000     998 cc
# 213   Third Party insurance    Diesel      5       30000    1995 cc
# 228   Third Party insurance    Petrol      6       20000    1451 cc
# 231   Third Party insurance    Diesel      5       32000    1995 cc
# 269   Third Party insurance    Diesel      5       32000    1995 cc
# 272   Third Party insurance    Petrol      4       40000    1998 cc
# 361   Third Party insurance    Diesel      5       80000    1498 cc
# 367   Third Party insurance    Petrol      5      110000    1497 cc
# 404   Third Party insurance    Diesel      7       20000    1996 cc
# 466   Third Party insurance    Diesel      5       10000    1950 cc
# 624   Third Party insurance    Diesel      5       30000    1995 cc
# 692   Third Party insurance    Diesel      5       31500    1995 cc
# 1042  Third Party insurance    Petrol      5       60000    1199 cc
# 1171  Third Party insurance    Petrol      5       60000     998 cc
# 1233  Third Party insurance    Diesel      5       32141    1248 cc
# 1262  Third Party insurance    Petrol      5       10000     999 cc
# 1287  Third Party insurance    Petrol      5       70000    1197 cc
# 1291  Third Party insurance    Diesel      5       90000    1498 cc
# 1449  Third Party insurance    Petrol      5       90000    1984 cc
# 1485  Third Party insurance    Diesel      7       40000    2999 cc
# 1505  Third Party insurance    Diesel      5       80000    1968 cc
# 1549  Third Party insurance    Petrol      5       10000     999 cc
#
#      transmission   manufacturing_year  mileage(kmpl)  engine(cc)  \
# 116          2017       Power Steering        2993.00     26149.0
# 170          2014       Power Steering        1461.00      1085.0
# 210          2023       Power Steering         998.00     11841.0
# 213          2017       Power Steering        1995.00       188.0
# 228          2020  Power Windows Front        1451.00       141.0
# 231          2017       Power Steering        1995.00       188.0
# 269          2017       Power Steering        1995.00       188.0
# 272          2021       Power Steering        1998.00     18740.0
# 361          2014       Power Steering        1498.00       986.0
# 367          2011       Power Steering        1497.00   1186600.0
# 404          2021       Power Steering        1996.00     16762.0
# 466          2022       Power Steering         147.51       320.0
# 624          2017       Power Steering        1995.00       188.0
# 692          2017       Power Steering        1995.00       188.0
# 1042         2018       Power Steering        1199.00        84.0
# 1171         2011       Power Steering         998.00       671.0
# 1233         2017       Power Steering        1248.00       885.0
# 1262         2023       Power Steering         999.00      7102.0
# 1287         2017       Power Steering        1197.00      8186.0
# 1291         2015       Power Steering        1498.00      1032.0
# 1449         2014       Power Steering        1984.00       207.0
# 1485         2018       Power Steering        2999.00     17457.0
# 1505         2016       Power Steering        1968.00       143.0
# 1549         2022       Power Steering         999.00      6706.0
#
#       max_power(bhp)  torque(Nm)  price(in lakhs)  \
# 116          26149.0       620.0            55.00
# 170           1085.0       248.0             6.00
# 210          11841.0       172.0            11.70
# 213            188.0       400.0            19.50
# 228            141.0       250.0            17.50
# 231            188.0       400.0            18.20
# 269            188.0       400.0            19.50
# 272          18740.0       280.0            32.00
# 361            986.0       200.0             4.75
# 367        1186600.0   1464800.0             3.50
# 404          16762.0       420.0            32.00
# 466            320.0        17.0            42.00
# 624            188.0       400.0            18.20
# 692            188.0       400.0            19.50
# 1042            84.0       114.0             4.75
# 1171           671.0        90.0             1.70
# 1233           885.0       200.0             6.00
# 1262          7102.0        96.0             8.50
# 1287          8186.0     11375.0             4.00
# 1291          1032.0       250.0             3.50
# 1449           207.0       300.0             8.00
# 1485         17457.0       380.0            21.00
# 1505           143.0       320.0            15.30
# 1549          6706.0        91.0             3.98
#
#                            car_model      car_maker  origin_country
# 116               7Series730LdMSport            BMW         Germany
# 170     TerranoXV110PSLimitedEdition         Nissan           Japan
# 210               i20N-LineN8DCTBSVI        Hyundai     South Korea
# 213            X1sDrive20dExpedition            BMW         Germany
# 228               HectorPlusSmartDCT             MG  United Kingdom
# 231            X1sDrive20dExpedition            BMW         Germany
# 269            X1sDrive20dExpedition            BMW         Germany
# 272        2SeriesBlackShadowEdition            BMW         Germany
# 361                       CityiDTECV          Honda           Japan
# 367                       City1.5SMT          Honda           Japan
# 404       EndeavourTitaniumPlus4X4AT           Ford   United States
# 466        A-ClassLimousineA200dBSVI  Mercedes-Benz         Germany
# 624            X1sDrive20dExpedition            BMW         Germany
# 692            X1sDrive20dExpedition            BMW         Germany
# 1042              Tigor1.2RevotronXZ           Tata           India
# 1171                   WagonRLXMinor         Maruti           India
# 1233                    Ciaz1.3Alpha         Maruti           India
# 1262                MagniteXVPremium         Nissan           Japan
# 1287  Grandi101.2KappaSportzDualTone        Hyundai     South Korea
# 1291             Vento1.5TDIHighline     Volkswagen         Germany
# 1449     Q32.0TFSIQuattroPremiumPlus           Audi         Germany
# 1485                         MU-X2WD          Isuzu           Japan
# 1505              A335TDIPremiumPlus           Audi         Germany
# 1549               KWID1.0RXLOptBSVI        Renault          France

# %%
df = df.drop(df[curpt_rows].index)
df['ownsership'].value_counts().plot(kind='barh')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1104 entries, 0 to 1552
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            1104 non-null   object
#  1   insurance_validity  1104 non-null   object
#  2   fuel_type           1104 non-null   object
#  3   seats               1104 non-null   int64
#  4   kms_driven          1104 non-null   int64
#  5   ownsership          1104 non-null   object
#  6   transmission        1104 non-null   object
#  7   manufacturing_year  1104 non-null   object
#  8   mileage(kmpl)       1104 non-null   float64
#  9   engine(cc)          1104 non-null   float64
#  10  max_power(bhp)      1104 non-null   float64
#  11  torque(Nm)          1104 non-null   float64
#  12  price(in lakhs)     1104 non-null   float64
#  13  car_model           1104 non-null   object
#  14  car_maker           1104 non-null   object
#  15  origin_country      1104 non-null   object
# dtypes: float64(5), int64(2), object(9)
# memory usage: 146.6+ KB

# %%
df['transmission'].value_counts().plot(kind='barh')
plt.show()

# %%
df['manufacturing_year'] = df['manufacturing_year'].astype('int64')

df['manufacturing_year'].value_counts().plot(kind='barh')
plt.show()

# %%
counts = df['mileage(kmpl)'].value_counts()

plt.boxplot(counts,vert=False)
plt.show()

# %%
counts = df['engine(cc)']

plt.boxplot(counts,vert=False)
plt.show()

# %% [markdown]
# For our purposes,which is second hand car market,cars with cc > 8400 can be considered outliers.Looking at the data below,none of these cars will have the engine cc as given ,so these are clearly wrong

# %%
curpt_rows2 = df['engine(cc)'] > 8400

df[curpt_rows2]
# Out:
#                                           car_name     insurance_validity  \
# 79                         2018 Mahindra XUV500 W5  Third Party insurance
# 142               2020 Mercedes-Benz GLE 300d BSVI               Zero Dep
# 145               2022 Mercedes-Benz GLE 300d BSVI               Zero Dep
# 146           2021 Toyota Fortuner Legender 4x2 AT          Comprehensive
# 160        2019 Mercedes-Benz AMG C43 4MATIC Coupe          Comprehensive
# 162   2021 Mahindra XUV700 AX7 AT Luxury Pack BSVI          Comprehensive
# 175                    2022 Volvo XC40 T4 R-Design               Zero Dep
# 276            2020 Kia Sonet GTX Plus Diesel BSVI               Zero Dep
# 313                    2021 Audi Q2 Premium Plus I          Comprehensive
# 396     2022 Mercedes-Benz AMG GLC 43 4MATIC Coupe          Comprehensive
# 454           2022 Mercedes-Benz AMG GLA 35 4MATIC  Third Party insurance
# 460         2022 Mercedes-Benz S-Class S 350d BSVI          Comprehensive
# 467             2022 Mercedes-Benz GLS 400d 4MATIC          Comprehensive
# 477                  2023 Mahindra XUV300 W6 Turbo  Third Party insurance
# 547        2022 Mahindra XUV700 AX7 AT Luxury Pack          Comprehensive
# 553                    2012 Maruti Swift Dzire LXI          Comprehensive
# 606         2023 Mercedes-Benz S-Class S450 4Matic          Comprehensive
# 622                     2021 Tata Altroz XE Diesel          Comprehensive
# 644                     2022 Maruti Swift LXI BSVI          Comprehensive
# 697     2022 Mercedes-Benz AMG GLC 43 4MATIC Coupe          Comprehensive
# 705        2023 Mercedes-Benz GLS 400d 4MATIC BSVI  Third Party insurance
# 791        2022 Mercedes-Benz AMG A 35 4MATIC BSVI          Comprehensive
# 831                    2022 Mercedes-Benz GLE 300d          Comprehensive
# 839             2021 Toyota Fortuner 4X4 Diesel AT          Comprehensive
# 902                           2014 Maruti Ritz VXi          Comprehensive
# 916        2021 Mercedes-Benz GLS 400d 4MATIC BSVI  Third Party insurance
# 919       2015 Mercedes-Benz M-Class ML 350 4Matic          Comprehensive
# 956                           2013 Maruti Ritz VXi          Comprehensive
# 995                    2020 Mercedes-Benz GLE 300d          Comprehensive
# 1011                          2013 Maruti Ritz VXi          Comprehensive
# 1101      2023 Mahindra XUV700 AX5 7 Str Diesel AT          Comprehensive
# 1116                   2012 Maruti Swift Dzire LXI  Third Party insurance
# 1245                       2020 Kia Seltos HTX IVT          Comprehensive
# 1247                       2020 Kia Seltos HTX IVT          Comprehensive
# 1283                        2015 Maruti Ertiga LDI          Comprehensive
# 1463       2020 Mercedes-Benz GLS 400d 4MATIC BSVI          Comprehensive
# 1513                          2021 Audi Q2 Premium          Comprehensive
# 1548      2020 Hyundai Creta SX Opt Diesel AT BSVI          Comprehensive
#
#      fuel_type  seats  kms_driven    ownsership transmission  \
# 79      Diesel      7       62000  Second Owner       Manual
# 142     Diesel      5       33000   First Owner    Automatic
# 145     Diesel      5       43703   First Owner    Automatic
# 146     Diesel      7       29800   First Owner    Automatic
# 160     Petrol      5       30000   First Owner    Automatic
# 162     Petrol      7       25000   First Owner    Automatic
# 175     Petrol      5       16433   First Owner    Automatic
# 276     Diesel      5       40000   First Owner       Manual
# 313     Petrol      5       28000   First Owner    Automatic
# 396     Petrol      5       16000   First Owner    Automatic
# 454     Petrol      5        9500   First Owner    Automatic
# 460     Diesel      5        7000   First Owner    Automatic
# 467     Diesel      7       19000  Second Owner    Automatic
# 477     Petrol      5       10000   First Owner       Manual
# 547     Petrol      7        5000   First Owner    Automatic
# 553     Petrol      5       94176   First Owner       Manual
# 606     Petrol      5        3500   First Owner    Automatic
# 622     Diesel      5       44275   First Owner       Manual
# 644     Petrol      5        8000   First Owner       Manual
# 697     Petrol      5       14000   First Owner    Automatic
# 705     Diesel      7       16000   First Owner    Automatic
# 791     Petrol      5       14000   First Owner    Automatic
# 831     Diesel      5       25000  Second Owner    Automatic
# 839     Diesel      7       23000   First Owner    Automatic
# 902     Petrol      5       48539  Second Owner       Manual
# 916     Diesel      7       46001   First Owner    Automatic
# 919     Diesel      5       76000   First Owner    Automatic
# 956     Petrol      5       80330   First Owner       Manual
# 995     Diesel      5       15000  Second Owner    Automatic
# 1011    Petrol      5      102511   First Owner       Manual
# 1101    Diesel      7       22468   First Owner    Automatic
# 1116    Petrol      5      105885   First Owner       Manual
# 1245    Petrol      5       82000   First Owner    Automatic
# 1247    Petrol      5       79000   First Owner    Automatic
# 1283    Diesel      7       65018   First Owner       Manual
# 1463    Diesel      7       34987   First Owner    Automatic
# 1513    Petrol      5        9700   First Owner    Automatic
# 1548    Diesel      5       35000   First Owner    Automatic
#
#       manufacturing_year  mileage(kmpl)    engine(cc)  max_power(bhp)  \
# 79                  2018         2179.0  1.528700e+04    1.528700e+04
# 142                 2020         1950.0  2.413800e+04    2.413800e+04
# 145                 2022         1950.0  2.413800e+04    2.413800e+04
# 146                 2021         2755.0  2.011500e+04    2.011500e+04
# 160                 2019         2996.0  3.848700e+04    3.848700e+04
# 162                 2021         1999.0  1.971300e+04    1.971300e+04
# 175                 2022         1969.0  1.874000e+04    1.874000e+04
# 276                 2020         1493.0  9.863000e+03    9.863000e+03
# 313                 2021         1984.0  1.877400e+04    1.877400e+04
# 396                 2022         2996.0  3.848700e+04    3.848700e+04
# 454                 2022         1991.0  3.017300e+04    3.017300e+04
# 460                 2022         2925.0  2.816100e+04    2.816100e+04
# 467                 2022         2925.0  3.258640e+12    3.258640e+12
# 477                 2023         1197.0  1.287300e+04    1.287300e+04
# 547                 2022         1999.0  1.971300e+04    1.971300e+04
# 553                 2012         1197.0  8.850000e+03    8.850000e+03
# 606                 2023         2999.0  3.620700e+04    3.620700e+04
# 622                 2021         1497.0  8.877000e+03    8.877000e+03
# 644                 2022         1197.0  8.850000e+03    8.850000e+03
# 697                 2022         2996.0  3.848700e+04    3.848700e+04
# 705                 2023         2925.0  3.258640e+12    3.258640e+12
# 791                 2022         1991.0  3.017300e+04    3.017300e+04
# 831                 2022         1950.0  2.413800e+04    2.413800e+04
# 839                 2021         2755.0  2.011500e+04    2.011500e+04
# 902                 2014         1197.0  8.580000e+03    8.580000e+03
# 916                 2021         2925.0  3.258640e+12    3.258640e+12
# 919                 2015         2987.0  1.652244e+09    1.652244e+09
# 956                 2013         1197.0  8.580000e+03    8.580000e+03
# 995                 2020         1950.0  2.413800e+04    2.413800e+04
# 1011                2013         1197.0  8.580000e+03    8.580000e+03
# 1101                2023         2198.0  1.823800e+04    1.823800e+04
# 1116                2012         1197.0  8.850000e+03    8.850000e+03
# 1245                2020         1497.0  1.134300e+04    1.134300e+04
# 1247                2020         1497.0  1.134300e+04    1.134300e+04
# 1283                2015         1248.0  8.850000e+03    8.850000e+03
# 1463                2020         2925.0  3.258640e+12    3.258640e+12
# 1513                2021         1984.0  1.877400e+04    1.877400e+04
# 1548                2020         1493.0  1.134500e+04    1.134500e+04
#
#       torque(Nm)  price(in lakhs)                  car_model      car_maker  \
# 79         360.0             8.50                   XUV500W5       Mahindra
# 142        500.0            78.00                GLE300dBSVI  Mercedes-Benz
# 145        500.0            82.90                GLE300dBSVI  Mercedes-Benz
# 146        500.0            44.00      FortunerLegender4x2AT         Toyota
# 160        520.0            67.00          AMGC434MATICCoupe  Mercedes-Benz
# 162        380.0            24.75  XUV700AX7ATLuxuryPackBSVI       Mahindra
# 175        300.0            43.75             XC40T4R-Design          Volvo
# 276        240.0            11.55     SonetGTXPlusDieselBSVI            Kia
# 313        320.0            26.50             Q2PremiumPlusI           Audi
# 396        520.0            83.00        AMGGLC434MATICCoupe  Mercedes-Benz
# 454        400.0            56.50             AMGGLA354MATIC  Mercedes-Benz
# 460        600.0             1.55           S-ClassS350dBSVI  Mercedes-Benz
# 467        700.0             1.15              GLS400d4MATIC  Mercedes-Benz
# 477        230.0            11.70              XUV300W6Turbo       Mahindra
# 547        380.0            26.50      XUV700AX7ATLuxuryPack       Mahindra
# 553        113.0             2.67              SwiftDzireLXI         Maruti
# 606        500.0             1.78          S-ClassS4504Matic  Mercedes-Benz
# 622        200.0             6.20             AltrozXEDiesel           Tata
# 644        113.0             5.95               SwiftLXIBSVI         Maruti
# 697        520.0            81.90        AMGGLC434MATICCoupe  Mercedes-Benz
# 705        700.0             1.32          GLS400d4MATICBSVI  Mercedes-Benz
# 791        400.0            48.50           AMGA354MATICBSVI  Mercedes-Benz
# 831        500.0            79.90                    GLE300d  Mercedes-Benz
# 839        500.0            43.00        Fortuner4X4DieselAT         Toyota
# 902        114.0             3.21                    RitzVXi         Maruti
# 916        700.0             1.06          GLS400d4MATICBSVI  Mercedes-Benz
# 919        510.0            19.99         M-ClassML3504Matic  Mercedes-Benz
# 956        114.0             2.93                    RitzVXi         Maruti
# 995        500.0            74.50                    GLE300d  Mercedes-Benz
# 1011       114.0             2.49                    RitzVXi         Maruti
# 1101       450.0            22.00      XUV700AX57StrDieselAT       Mahindra
# 1116       113.0             3.27              SwiftDzireLXI         Maruti
# 1245       144.0            13.90               SeltosHTXIVT            Kia
# 1247       144.0            12.90               SeltosHTXIVT            Kia
# 1283       200.0             4.75                  ErtigaLDI         Maruti
# 1463       700.0             1.10          GLS400d4MATICBSVI  Mercedes-Benz
# 1513       320.0            35.49                  Q2Premium           Audi
# 1548       250.0            17.41     CretaSXOptDieselATBSVI        Hyundai
#
#      origin_country
# 79            India
# 142         Germany
# 145         Germany
# 146           Japan
# 160         Germany
# 162           India
# 175          Sweden
# 276     South Korea
# 313         Germany
# 396         Germany
# 454         Germany
# 460         Germany
# 467         Germany
# 477           India
# 547           India
# 553           India
# 606         Germany
# 622           India
# 644           India
# 697         Germany
# 705         Germany
# 791         Germany
# 831         Germany
# 839           Japan
# 902           India
# 916         Germany
# 919         Germany
# 956           India
# 995         Germany
# 1011          India
# 1101          India
# 1116          India
# 1245    South Korea
# 1247    South Korea
# 1283          India
# 1463        Germany
# 1513        Germany
# 1548    South Korea

# %% [markdown]
# Deleting corrupted rows

# %%
df = df.drop(df[curpt_rows2].index)
counts = df['engine(cc)']

plt.boxplot(counts,vert=False)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1066 entries, 0 to 1552
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            1066 non-null   object
#  1   insurance_validity  1066 non-null   object
#  2   fuel_type           1066 non-null   object
#  3   seats               1066 non-null   int64
#  4   kms_driven          1066 non-null   int64
#  5   ownsership          1066 non-null   object
#  6   transmission        1066 non-null   object
#  7   manufacturing_year  1066 non-null   int64
#  8   mileage(kmpl)       1066 non-null   float64
#  9   engine(cc)          1066 non-null   float64
#  10  max_power(bhp)      1066 non-null   float64
#  11  torque(Nm)          1066 non-null   float64
#  12  price(in lakhs)     1066 non-null   float64
#  13  car_model           1066 non-null   object
#  14  car_maker           1066 non-null   object
#  15  origin_country      1066 non-null   object
# dtypes: float64(5), int64(3), object(8)
# memory usage: 141.6+ KB

# %%
counts = df['max_power(bhp)']

plt.boxplot(counts,vert=False)
plt.show()

# %% [markdown]
# Same reasoning as the engine(cc) above

# %%
df = df.drop(df.index[df['max_power(bhp)'] >= 3000])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1019 entries, 0 to 1552
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            1019 non-null   object
#  1   insurance_validity  1019 non-null   object
#  2   fuel_type           1019 non-null   object
#  3   seats               1019 non-null   int64
#  4   kms_driven          1019 non-null   int64
#  5   ownsership          1019 non-null   object
#  6   transmission        1019 non-null   object
#  7   manufacturing_year  1019 non-null   int64
#  8   mileage(kmpl)       1019 non-null   float64
#  9   engine(cc)          1019 non-null   float64
#  10  max_power(bhp)      1019 non-null   float64
#  11  torque(Nm)          1019 non-null   float64
#  12  price(in lakhs)     1019 non-null   float64
#  13  car_model           1019 non-null   object
#  14  car_maker           1019 non-null   object
#  15  origin_country      1019 non-null   object
# dtypes: float64(5), int64(3), object(8)
# memory usage: 135.3+ KB

# %%
counts = df['torque(Nm)']

plt.boxplot(counts,vert=False)
plt.show()

# %%
curpt_rows3 = df[df['torque(Nm)'] > 20000]
curpt_rows3
# Out:
#                                           car_name     insurance_validity  \
# 8             2015 Mercedes-Benz S-Class S 350 CDI          Comprehensive
# 20                     2021 MG Gloster Savvy 6-Str          Comprehensive
# 64    2021 Mercedes-Benz C-Class Progressive C 200          Comprehensive
# 68             2023 BMW 5 Series 530i M Sport BSVI               Zero Dep
# 198             2019 Mercedes-Benz S-Class S 350 d          Comprehensive
# ...                                            ...                    ...
# 1492                2019 BMW X7 xDrive 40i M Sport          Comprehensive
# 1507                      2010 Honda City 1.5 V MT          Comprehensive
# 1509          2022 Volvo XC 90 B6 Inscription 7STR  Third Party insurance
# 1528                2021 BMW X7 xDrive 40i M Sport               Zero Dep
# 1531            2012 Hyundai i20 1.2 Sportz Option  Third Party insurance
#
#      fuel_type  seats  kms_driven    ownsership transmission  \
# 8       Diesel      5       68000  Second Owner    Automatic
# 20      Diesel      6       35000   First Owner    Automatic
# 64      Petrol      5       25000  Second Owner    Automatic
# 68      Petrol      5       20000   First Owner    Automatic
# 198     Diesel      5       27200   First Owner    Automatic
# ...        ...    ...         ...           ...          ...
# 1492    Petrol      7       28000   First Owner    Automatic
# 1507    Petrol      5       32000   First Owner       Manual
# 1509    Petrol      7       10000   First Owner    Automatic
# 1528    Petrol      7        7000   First Owner    Automatic
# 1531    Petrol      5       49303  Second Owner       Manual
#
#       manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  \
# 8                   2015          13.50      2987.0          2987.0
# 20                  2021          12.40      1996.0          1996.0
# 64                  2021          11.90      1950.0          1950.0
# 68                  2023          14.82      1998.0          1998.0
# 198                 2019          13.50      2925.0          2925.0
# ...                  ...            ...         ...             ...
# 1492                2019          10.54      2998.0          2998.0
# 1507                2010          17.00      1497.0          1497.0
# 1509                2022          17.20      1969.0          1969.0
# 1528                2021          10.54      2998.0          2998.0
# 1531                2012          17.00      1197.0          1197.0
#
#       torque(Nm)  price(in lakhs)               car_model      car_maker  \
# 8        25479.0            42.00          S-ClassS350CDI  Mercedes-Benz
# 20       21501.0            35.00       GlosterSavvy6-Str             MG
# 64       20115.0            40.75  C-ClassProgressiveC200  Mercedes-Benz
# 68       24808.0            65.00   5Series530iMSportBSVI            BMW
# 198      28161.0            77.00            S-ClassS350d  Mercedes-Benz
# ...          ...              ...                     ...            ...
# 1492     33525.0            99.00       X7xDrive40iMSport            BMW
# 1507   1186600.0             2.40              City1.5VMT          Honda
# 1509     29589.0            85.00   XC90B6Inscription7STR          Volvo
# 1528     33525.0             1.15       X7xDrive40iMSport            BMW
# 1531    805200.0             2.80      i201.2SportzOption        Hyundai
#
#       origin_country
# 8            Germany
# 20    United Kingdom
# 64           Germany
# 68           Germany
# 198          Germany
# ...              ...
# 1492         Germany
# 1507           Japan
# 1509          Sweden
# 1528         Germany
# 1531     South Korea
#
# [63 rows x 16 columns]

# %% [markdown]
# Getting rid of outliers

# %%
df = df.drop(curpt_rows3.index)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 956 entries, 0 to 1552
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            956 non-null    object
#  1   insurance_validity  956 non-null    object
#  2   fuel_type           956 non-null    object
#  3   seats               956 non-null    int64
#  4   kms_driven          956 non-null    int64
#  5   ownsership          956 non-null    object
#  6   transmission        956 non-null    object
#  7   manufacturing_year  956 non-null    int64
#  8   mileage(kmpl)       956 non-null    float64
#  9   engine(cc)          956 non-null    float64
#  10  max_power(bhp)      956 non-null    float64
#  11  torque(Nm)          956 non-null    float64
#  12  price(in lakhs)     956 non-null    float64
#  13  car_model           956 non-null    object
#  14  car_maker           956 non-null    object
#  15  origin_country      956 non-null    object
# dtypes: float64(5), int64(3), object(8)
# memory usage: 127.0+ KB

# %%
counts = df['torque(Nm)']

plt.boxplot(counts,vert=False)
plt.show()

# %%
counts = df['price(in lakhs)']

plt.boxplot(counts,vert=False)
plt.show()

# %% [markdown]
# The Price of cars is in Lakhs. (1 Lakh = 100,000). 1 USD = ~83 INR (Indian Rupees).
#
# So, INR 100,000 = ~ USD 1200.
#
# So, we will delete all values for price that are greater than 17 Lakhs (~USD 20,000)

# %%
curpt_rows4 = df[df['price(in lakhs)'] > 17]
curpt_rows4.count()
# Out:
# car_name              161
# insurance_validity    161
# fuel_type             161
# seats                 161
# kms_driven            161
# ownsership            161
# transmission          161
# manufacturing_year    161
# mileage(kmpl)         161
# engine(cc)            161
# max_power(bhp)        161
# torque(Nm)            161
# price(in lakhs)       161
# car_model             161
# car_maker             161
# origin_country        161
# dtype: int64

# %%
df = df.drop(curpt_rows4.index)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 795 entries, 1 to 1552
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            795 non-null    object
#  1   insurance_validity  795 non-null    object
#  2   fuel_type           795 non-null    object
#  3   seats               795 non-null    int64
#  4   kms_driven          795 non-null    int64
#  5   ownsership          795 non-null    object
#  6   transmission        795 non-null    object
#  7   manufacturing_year  795 non-null    int64
#  8   mileage(kmpl)       795 non-null    float64
#  9   engine(cc)          795 non-null    float64
#  10  max_power(bhp)      795 non-null    float64
#  11  torque(Nm)          795 non-null    float64
#  12  price(in lakhs)     795 non-null    float64
#  13  car_model           795 non-null    object
#  14  car_maker           795 non-null    object
#  15  origin_country      795 non-null    object
# dtypes: float64(5), int64(3), object(8)
# memory usage: 105.6+ KB

# %%
counts = df['price(in lakhs)']

plt.boxplot(counts,vert=False)
plt.show()

# %%
df['ownsership'] = df['ownsership'].replace({'First Owner' : 3,
                                              'Second Owner': 2,
                                              'Third Owner' : 1
                                              })

df['transmission'] = df['transmission'].replace({'Manual' : 1,
                                                  'Automatic' : 2
                                                 })

df['fuel_type'] = df['fuel_type'].replace({'Petrol' : 3,
                                                'Diesel' : 2,
                                                'CNG' : 1                                         
                                           })

df = df.drop(['car_maker','car_model'],axis=1)

df.head(10)
# Out:
# /var/folders/9l/kb_h965x30nf_8tn9qhb48p40000gn/T/ipykernel_10759/2970047280.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['ownsership'] = df['ownsership'].replace({'First Owner' : 3,
# /var/folders/9l/kb_h965x30nf_8tn9qhb48p40000gn/T/ipykernel_10759/2970047280.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['transmission'] = df['transmission'].replace({'Manual' : 1,
# /var/folders/9l/kb_h965x30nf_8tn9qhb48p40000gn/T/ipykernel_10759/2970047280.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['fuel_type'] = df['fuel_type'].replace({'Petrol' : 3,
#                                              car_name     insurance_validity  \
# 1   2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI          Comprehensive
# 3                            2019 Kia Seltos GTX Plus          Comprehensive
# 5                        2017 Honda Jazz 1.2 S i VTEC  Third Party insurance
# 6        2018 Hyundai Grand i10 1.2 Kappa Sportz BSIV          Comprehensive
# 7                           2018 Hyundai Creta 1.6 SX          Comprehensive
# 9                2019 Tata Nexon 1.2 Revotron XZ Plus          Comprehensive
# 10                             2020 Honda City VX CVT          Comprehensive
# 11                            2021 Renault Duster RXS          Comprehensive
# 12                    2014 BMW 3 Series 320d Prestige  Third Party insurance
# 13               2021 Hyundai Venue SX Plus Turbo DCT          Comprehensive
#
#     fuel_type  seats  kms_driven  ownsership  transmission  \
# 1           3      5       30615           3             2
# 3           3      5       18378           3             1
# 5           3      5       42000           3             1
# 6           3      5       36739           3             1
# 7           3      5       76000           3             1
# 9           3      5       28783           3             1
# 10          3      5       40000           3             2
# 11          3      5       17382           3             1
# 12          2      5      120000           3             2
# 13          3      5       17000           3             2
#
#     manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# 1                 2020          17.40       999.0           999.0      9863.0
# 3                 2019          16.50      1353.0          1353.0     13808.0
# 5                 2017          18.70      1199.0          1199.0       887.0
# 6                 2018          18.90      1197.0          1197.0      8186.0
# 7                 2018          15.80      1591.0          1591.0      1213.0
# 9                 2019          17.00      1198.0          1198.0      1085.0
# 10                2020          17.40      1497.0          1497.0      1176.0
# 11                2021          16.42      1498.0          1498.0     10455.0
# 12                2014          18.88      1995.0          1995.0       184.0
# 13                2021          18.15       998.0           998.0     11835.0
#
#     price(in lakhs) origin_country
# 1              8.99          Japan
# 3             13.56    South Korea
# 5              5.45          Japan
# 6              5.12    South Korea
# 7              9.30    South Korea
# 9              8.02          India
# 10            10.95          Japan
# 11             8.99         France
# 12             7.45        Germany
# 13            10.95    South Korea

# %% [markdown]
# We have deleted the car_name, car_maker and car_model cols, as these are no longer necessary. These were created to get the country of the company (which will be used in further analysis)

# %%
df = df.drop('car_name',axis=1)

num_col = df.select_dtypes(include=['int64','float64']).columns
cat_col = df.select_dtypes(exclude=['int64','float64']).columns

# %%
df[cat_col]
# Out:
#          insurance_validity origin_country
# 1             Comprehensive          Japan
# 3             Comprehensive    South Korea
# 5     Third Party insurance          Japan
# 6             Comprehensive    South Korea
# 7             Comprehensive    South Korea
# ...                     ...            ...
# 1546          Comprehensive          Japan
# 1547  Third Party insurance          India
# 1550          Comprehensive          Japan
# 1551          Comprehensive        Germany
# 1552          Comprehensive          India
#
# [795 rows x 2 columns]

# %%
df[num_col]
# Out:
#       fuel_type  seats  kms_driven  ownsership  transmission  \
# 1             3      5       30615           3             2
# 3             3      5       18378           3             1
# 5             3      5       42000           3             1
# 6             3      5       36739           3             1
# 7             3      5       76000           3             1
# ...         ...    ...         ...         ...           ...
# 1546          3      5       19446           3             2
# 1547          1      7       26500           3             1
# 1550          3      5       49000           3             1
# 1551          3      5       40000           2             1
# 1552          3      5       34756           3             1
#
#       manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  \
# 1                   2020          17.40       999.0           999.0
# 3                   2019          16.50      1353.0          1353.0
# 5                   2017          18.70      1199.0          1199.0
# 6                   2018          18.90      1197.0          1197.0
# 7                   2018          15.80      1591.0          1591.0
# ...                  ...            ...         ...             ...
# 1546                2018          18.20      1199.0          1199.0
# 1547                2022          26.11      1462.0          1462.0
# 1550                2017          17.50      1199.0          1199.0
# 1551                2018          18.78       999.0           999.0
# 1552                2018          20.85      1197.0          1197.0
#
#       torque(Nm)  price(in lakhs)
# 1         9863.0             8.99
# 3        13808.0            13.56
# 5          887.0             5.45
# 6         8186.0             5.12
# 7         1213.0             9.30
# ...          ...              ...
# 1546       887.0             6.50
# 1547      8663.0            11.50
# 1550       887.0             5.85
# 1551        75.0             4.75
# 1552      8314.0             6.10
#
# [795 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 795 entries, 1 to 1552
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   insurance_validity  795 non-null    object
#  1   fuel_type           795 non-null    int64
#  2   seats               795 non-null    int64
#  3   kms_driven          795 non-null    int64
#  4   ownsership          795 non-null    int64
#  5   transmission        795 non-null    int64
#  6   manufacturing_year  795 non-null    int64
#  7   mileage(kmpl)       795 non-null    float64
#  8   engine(cc)          795 non-null    float64
#  9   max_power(bhp)      795 non-null    float64
#  10  torque(Nm)          795 non-null    float64
#  11  price(in lakhs)     795 non-null    float64
#  12  origin_country      795 non-null    object
# dtypes: float64(5), int64(6), object(2)
# memory usage: 87.0+ KB

# %% [markdown]
# Encoding the following cols for further analysis

# %%
df = pd.get_dummies(df,columns=['insurance_validity','origin_country'])
df
# Out:
#       fuel_type  seats  kms_driven  ownsership  transmission  \
# 1             3      5       30615           3             2
# 3             3      5       18378           3             1
# 5             3      5       42000           3             1
# 6             3      5       36739           3             1
# 7             3      5       76000           3             1
# ...         ...    ...         ...         ...           ...
# 1546          3      5       19446           3             2
# 1547          1      7       26500           3             1
# 1550          3      5       49000           3             1
# 1551          3      5       40000           2             1
# 1552          3      5       34756           3             1
#
#       manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  \
# 1                   2020          17.40       999.0           999.0
# 3                   2019          16.50      1353.0          1353.0
# 5                   2017          18.70      1199.0          1199.0
# 6                   2018          18.90      1197.0          1197.0
# 7                   2018          15.80      1591.0          1591.0
# ...                  ...            ...         ...             ...
# 1546                2018          18.20      1199.0          1199.0
# 1547                2022          26.11      1462.0          1462.0
# 1550                2017          17.50      1199.0          1199.0
# 1551                2018          18.78       999.0           999.0
# 1552                2018          20.85      1197.0          1197.0
#
#       torque(Nm)  ...  origin_country_Czech Republic  origin_country_France  \
# 1         9863.0  ...                          False                  False
# 3        13808.0  ...                          False                  False
# 5          887.0  ...                          False                  False
# 6         8186.0  ...                          False                  False
# 7         1213.0  ...                          False                  False
# ...          ...  ...                            ...                    ...
# 1546       887.0  ...                          False                  False
# 1547      8663.0  ...                          False                  False
# 1550       887.0  ...                          False                  False
# 1551        75.0  ...                          False                  False
# 1552      8314.0  ...                          False                  False
#
#       origin_country_Germany  origin_country_India  origin_country_Italy  \
# 1                      False                 False                 False
# 3                      False                 False                 False
# 5                      False                 False                 False
# 6                      False                 False                 False
# 7                      False                 False                 False
# ...                      ...                   ...                   ...
# 1546                   False                 False                 False
# 1547                   False                  True                 False
# 1550                   False                 False                 False
# 1551                    True                 False                 False
# 1552                   False                  True                 False
#
#       origin_country_Japan  origin_country_South Korea  \
# 1                     True                       False
# 3                    False                        True
# 5                     True                       False
# 6                    False                        True
# 7                    False                        True
# ...                    ...                         ...
# 1546                  True                       False
# 1547                 False                       False
# 1550                  True                       False
# 1551                 False                       False
# 1552                 False                       False
#
#       origin_country_Uinted states  origin_country_United Kingdom  \
# 1                            False                          False
# 3                            False                          False
# 5                            False                          False
# 6                            False                          False
# 7                            False                          False
# ...                            ...                            ...
# 1546                         False                          False
# 1547                         False                          False
# 1550                         False                          False
# 1551                         False                          False
# 1552                         False                          False
#
#       origin_country_United States
# 1                            False
# 3                            False
# 5                            False
# 6                            False
# 7                            False
# ...                            ...
# 1546                         False
# 1547                         False
# 1550                         False
# 1551                         False
# 1552                         False
#
# [795 rows x 24 columns]

# %% [markdown]
# # Feature Engineering

# %%
corr_matrix = df.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Collinearity
# As we can see in the above correlation matrix, this is a case of perfect Collinearity between max_power(bhp) and engine(cc). This makes them redundant, so we are deleting max_power(bhp)

# %%
df = df.drop(columns='max_power(bhp)')

# %%
corr_matrix = df.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
X = df.drop('price(in lakhs)',axis=1)
Y = df['price(in lakhs)']

# %% [markdown]
# Splitting the data

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=0)

# %% [markdown]
# # Model Training
#
# As mentioned previously, we are going to be training 2 models (Linear Regression and AdaBoost Regressor).
#
# We will begin will getting the best features for both the models using RFECV (Recursive Feature Elimination with Cross-Validation)

# %%
lr_model = LinearRegression()

rfecv_lr = RFECV(estimator=lr_model, step=1, cv=5, scoring='neg_mean_squared_error')
rfecv_lr.fit(X_train, y_train)

selected_features_lr = X_train.columns[rfecv_lr.support_]
X_train_lr = rfecv_lr.transform(X_train)
X_test_lr = rfecv_lr.transform(X_test)

print(f"Selected Features for Linear Regression: {selected_features_lr}")
# Out:
# Selected Features for Linear Regression: Index(['fuel_type', 'seats', 'ownsership', 'transmission',
#        'manufacturing_year', 'mileage(kmpl)', 'engine(cc)', 'torque(Nm)',
#        'insurance_validity_Comprehensive',
#        'insurance_validity_Third Party insurance',
#        'insurance_validity_Zero Dep', 'origin_country_Czech Republic',
#        'origin_country_France', 'origin_country_Germany',
#        'origin_country_India', 'origin_country_Italy', 'origin_country_Japan',
#        'origin_country_South Korea', 'origin_country_Uinted states',
#        'origin_country_United Kingdom', 'origin_country_United States'],
#       dtype='object')

# %%
base_estimator = DecisionTreeRegressor(max_depth=1)
ada_model = AdaBoostRegressor(base_estimator, n_estimators=100, learning_rate=0.1, random_state=42)

rfecv_ada = RFECV(estimator=ada_model,step=1, cv=5, scoring='neg_mean_squared_error')
rfecv_ada.fit(X_train,y_train)

selected_features_ada = X_train.columns[rfecv_ada.support_]
X_train_ada = rfecv_ada.transform(X_train)
X_test_ada = rfecv_ada.transform(X_test)

print(f"Selected Features for AdaBoost Regressor: {selected_features_ada}")
# Out:
# Selected Features for AdaBoost Regressor: Index(['transmission', 'manufacturing_year', 'engine(cc)', 'torque(Nm)'], dtype='object')

# %% [markdown]
# # Model Evaluation

# %%
def evaluate_model(y_test, y_pred):
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = mse ** 0.5
    r2 = r2_score(y_test, y_pred)
    return mae, mse, rmse, r2

lr_model.fit(X_train_lr, y_train)
y_pred_lr = lr_model.predict(X_test_lr)
mae_lr, mse_lr, rmse_lr, r2_lr = evaluate_model(y_test, y_pred_lr)

ada_model.fit(X_train_ada, y_train)
y_pred_ada = ada_model.predict(X_test_ada)
mae_ada, mse_ada, rmes_ada, r2_ada = evaluate_model(y_test, y_pred_ada)

print(f"Linear Regression - MAE: {mae_lr}, MSE: {mse_lr}, RMSE: {rmse_lr}, R2: {r2_lr}")
print(f"Best AdaBoost Regressor - MAE: {mae_ada}, MSE: {mse_ada}, RMSE: {mse_ada}, R2: {r2_ada}")
# Out:
# Linear Regression - MAE: 1.3096515410808993, MSE: 3.041565655110328, RMSE: 1.7440085020177878, R2: 0.7519950200777901
# Best AdaBoost Regressor - MAE: 1.9931586398419514, MSE: 6.682123229039241, RMSE: 6.682123229039241, R2: 0.45514908268666066

# %% [markdown]
# ## Interpretation
#
# Mean Absolute Error (MAE): Linear Regression has a lower MAE (1.362) compared to AdaBoost (1.993), indicating that, on average, the predictions of the Linear Regression model are closer to the actuvalues than those of the AdaBoost Regressor.
#
# Mean Squared Error (MSE) and Root Mean Squared Error (RMSE): Linear Regression also has lower MSE (3.578) and RMSE (1.892) compared to AdaBoost (MSE: 6.682, RMSE: 2.585). This further suggests that Linear Regression provides more accurate predictions with fewer large errors.
#
# R2: The R2 value for Linear Regression (0.708) is significantly higher than that of AdaBoost (0.455). This indicates that Linear Regression explains about 70.8% of the variance in the car prices, while AdaBoost explains only about 45.5%. Higher R2 means that the model fits the data better.

# %%
residuals_lr = y_test - y_pred_lr
residuals_ada = y_test - y_pred_ada

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.scatter(y_test, residuals_lr)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('Actual Prices')
plt.ylabel('Residuals')
plt.title('Linear Regression Residuals')

plt.subplot(1, 2, 2)
plt.scatter(y_test, residuals_ada)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('Actual Prices')
plt.ylabel('Residuals')
plt.title('Linear Regression Residuals')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusion
#
# This was a fun project, and I learnt a lot from this.
#
# To Recap, we got the data from Kaggle, and first cleaned the dataset. We explored each col in the dataset to see if there were duplicates, or if there were any corrupted values/rows. We then checked for collinearity and found out that a couple of rows were perfectly collinear, making them redundant. We then got to feature engineering for both the models that we chose, and fit the data (with the selected features) to both models and evaluated it.
#
# We chose the evaluation metrics of MAE, MSE, RMSE and R2, instead of metrics like accuracy for the simple reason

# %% [markdown]
# ## Key Takeaways
#
# - Importance of Metric Selection for model evaluation
#
#   For our particular scenario, MAE, MSE, RMSE, and R2 are crucial for evaluating our models. They provide detailed insights into the prediction accuracy and modelfit, which accuracy cannot. This is because this is a regression problem and not a classification problem. In a classification problem, using Accuracy for model evaluation might have been the way to go. Because when it comes to regression, we are more interested in how close we are to the answer rather than if we are exactly correct For ex: If we buy a car for $15,000, but our model predicts $14,800, Accuracy will take a hit, but in reality this is a very good estimate. We are more interested in how close we are to the actual answer rather than whether we predict the exact price
#
# - Importance of Feature Engineering
#
#   We used RFECV as the method for Feature Engineering. This method worked well for the Linear Regression. But it did not work so well for the AdaBoost Regressor, as evidenced by the number of features selected. It is clear that, even within the same dataset, for different models, we might require different methods of selecting features, in order to optimize the model, making it better and making it efficient.

# %% [markdown]
# ## What did not work
#
# - As mentioned earlier, the feature engineering is a big let down, for the adaBoost Regressor. Maybe with a different feature engineering method, we might have had a better AdaBoost Regressor model.

# %% [markdown]
# ## Next Steps
#
# There is clearly room for improvement in the model training area. More so with the AdaBoost Regressor. The linear regression, although could be made better, sits pretty, having an R2 value of 0.708,which is a good starting point.

# %% [markdown]
# ## Ways to Improve
#
# Here is how we can potentially improve the AdaBoost Regressor.
#
#  -   Feature Engineering: We can see that the number of features selected is just 4, when we used RFECV. We can potentially try to using a different method for selecting the features.
#
#  -   Hyperparameters: In this notebook, we did not use any hyperparameter tuning. Incorporating this might help make this model better.
